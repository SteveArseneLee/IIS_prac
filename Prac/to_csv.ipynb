# %%
import pandas as pd

file = pd.read_csv('법정동코드 전체자료.txt', encoding='euc-kr')
new_file = file.to_csv('municode.csv', encoding='utf-8-sig', index=None)

# %%
mun = pd.read_csv('municode.csv')
mun.head()
# Out:
#                법정동코드\t법정동명\t폐지여부
# 0          1100000000\t서울특별시\t존재
# 1      1111000000\t서울특별시 종로구\t존재
# 2  1111010100\t서울특별시 종로구 청운동\t존재
# 3  1111010200\t서울특별시 종로구 신교동\t존재
# 4  1111010300\t서울특별시 종로구 궁정동\t존재

# %%
# for a in range(5):
# for i in mun:
#     print(i)
import csv

with open('test.csv', newline='') as read_obj:
    csv_r = csv.reader(read_obj)
    next(csv_r)
    list_mun = list(csv_r)
print(list_mun)
# Out:
# [['1100000000\t서울특별시\t존재'], ['1111000000\t서울특별시 종로구\t존재'], ['1111010100\t서울특별시 종로구 청운동\t존재'], ['1111010200\t서울특별시 종로구 신교동\t존재'], ['1111010300\t서울특별시 종로구 궁정동\t존재'], ['1111010400\t서울특별시 종로구 효자동\t존재'], ['1114011500\t서울특별시 중구 남대문로2가\t존재'], ['1114011600\t서울특별시 중구 남대문로3가\t존재'], ['1114011700\t서울특별시 중구 남대문로4가\t존재'], ['1114011800\t서울특별시 중구 남대문로5가\t존재'], ['1114011900\t서울특별시 중구 봉래동1가\t존재'], ['1114012000\t서울특별시 중구 봉래동2가\t존재'], ['1114012100\t서울특별시 중구 회현동1가\t존재'], ['1114012200\t서울특별시 중구 회현동2가\t존재'], ['1114012300\t서울특별시 중구 회현동3가\t존재'], ['1114012400\t서울특별시 중구 충무로1가\t존재'], ['1114012500\t서울특별시 중구 충무로2가\t존재'], ['1114012600\t서울특별시 중구 명동1가\t존재'], ['1114012700\t서울특별시 중구 명동2가\t존재']]

# %%
for i in list_mun:
    x = i[0].split('\t')
    print(x)
    print(x[0][:5])
    print(x[1])
    for m in list(x[1]):
        print(m)
        if m == "구":
            break
# Out:
# ['1100000000', '서울특별시', '존재']
# 11000
# 서울특별시
# 서
# 울
# 특
# 별
# 시
# ['1111000000', '서울특별시 종로구', '존재']
# 11110
# 서울특별시 종로구
# 서
# 울
# 특
# 별
# 시
#
# 종
# 로
# 구
# ['1111010100', '서울특별시 종로구 청운동', '존재']
# 11110
# 서울특별시 종로구 청운동
# 서
# 울
# 특
# 별
# 시
#
# 종
# 로
# 구
# ['1111010200', '서울특별시 종로구 신교동', '존재']
# 11110
# 서울특별시 종로구 신교동
# 서
# 울
# 특
# 별
# 시
#
# 종
# 로
# 구
# ['1111010300', '서울특별시 종로구 궁정동', '존재']
# 11110
# 서울특별시 종로구 궁정동
# 서
# 울
# 특
# 별
# 시
#
# 종
# 로
# 구
# ['1111010400', '서울특별시 종로구 효자동', '존재']
# 11110
# 서울특별시 종로구 효자동
# 서
# 울
# 특
# 별
# 시
#
# 종
# 로
# 구
# ['1114011500', '서울특별시 중구 남대문로2가', '존재']
# 11140
# 서울특별시 중구 남대문로2가
# 서
# 울
# 특
# 별
# 시
#
# 중
# 구
# ['1114011600', '서울특별시 중구 남대문로3가', '존재']
# 11140
# 서울특별시 중구 남대문로3가
# 서
# 울
# 특
# 별
# 시
#
# 중
# 구
# ['1114011700', '서울특별시 중구 남대문로4가', '존재']
# 11140
# 서울특별시 중구 남대문로4가
# 서
# 울
# 특
# 별
# 시
#
# 중
# 구
# ['1114011800', '서울특별시 중구 남대문로5가', '존재']
# 11140
# 서울특별시 중구 남대문로5가
# 서
# 울
# 특
# 별
# 시
#
# 중
# 구
# ['1114011900', '서울특별시 중구 봉래동1가', '존재']
# 11140
# ...
